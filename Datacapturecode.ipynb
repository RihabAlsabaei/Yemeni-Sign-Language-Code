# %%
import cv2
import time
import numpy as np
import os
def nothing(x):
    pass
image_x, image_y = 64, 64
def create_folder(folder_name):
    if not os.path.exists('dataset/training_data/' + folder_name):
        os.mkdir('dataset/training_data/' + folder_name)
    if not os.path.exists('dataset/test_data/' + folder_name):
        os.mkdir('dataset/test_data/' + folder_name)


def capture_images(ges_name):
    create_folder(str(ges_name))

    cam = cv2.VideoCapture(0)

    cv2.namedWindow("test")

    img_counter = 0
    t_counter = 1
    training_set_image_name = 1
    test_set_image_name = 1
    listImage = [1, 2, 3, 4, 5]

    cv2.namedWindow("Trackbars")

    cv2.createTrackbar("L - H", "Trackbars", 0, 179, nothing)
    cv2.createTrackbar("L - S", "Trackbars", 0, 255, nothing)
    cv2.createTrackbar("L - V", "Trackbars", 0, 255, nothing)
    cv2.createTrackbar("U - H", "Trackbars", 179, 179, nothing)
    cv2.createTrackbar("U - S", "Trackbars", 255, 255, nothing)
    cv2.createTrackbar("U - V", "Trackbars", 255, 255, nothing)

    for loop in listImage:
        while True:

            ret, frame = cam.read()
            frame = cv2.flip(frame, 1)

            l_h = cv2.getTrackbarPos("L - H", "Trackbars")
            l_s = cv2.getTrackbarPos("L - S", "Trackbars")
            l_v = cv2.getTrackbarPos("L - V", "Trackbars")
            u_h = cv2.getTrackbarPos("U - H", "Trackbars")
            u_s = cv2.getTrackbarPos("U - S", "Trackbars")
            u_v = cv2.getTrackbarPos("U - V", "Trackbars")

            img = cv2.rectangle(frame, (425, 100), (625, 300), (0, 255, 0), thickness=2, lineType=8, shift=0)

            lower_blue = np.array([l_h, l_s, l_v])
            upper_blue = np.array([u_h, u_s, u_v])
            imcrop = img[102:298, 427:623]


            cv2.putText(frame, str(img_counter), (30, 400), cv2.FONT_HERSHEY_TRIPLEX, 1.5, (127, 127, 255))
            cv2.imshow("test", frame)


            if cv2.waitKey(1) == ord('c'):

                if t_counter <= 350:
                    img_name = "dataset/training_data/" + str(ges_name) + "/{}.png".format(training_set_image_name)
                    cv2.imwrite(img_name, imcrop)
                    print("{} written!".format(img_name))
                    training_set_image_name += 1

                if t_counter > 350 and t_counter <= 400:
                    img_name = "dataset/test_data/" + str(ges_name) + "/{}.png".format(test_set_image_name)
                    cv2.imwrite(img_name, imcrop)
                    print("{} written!".format(img_name))
                    test_set_image_name += 1
                    if test_set_image_name > 250:
                        break

                t_counter += 1
                if t_counter == 401:
                    t_counter = 1
                img_counter += 1


            elif cv2.waitKey(1) == 27:
                break

        if test_set_image_name > 250:
            break

    cam.release()
    cv2.destroyAllWindows()


ges_name = input("Enter gesture name: ")
capture_images(ges_name)
# Out:
# Enter gesture name: re
# dataset/training_data/re/1.png written!
# dataset/training_data/re/2.png written!
# dataset/training_data/re/3.png written!
# dataset/training_data/re/4.png written!
# dataset/training_data/re/5.png written!
# dataset/training_data/re/6.png written!
# dataset/training_data/re/7.png written!
# dataset/training_data/re/8.png written!
# dataset/training_data/re/9.png written!
# dataset/training_data/re/10.png written!
# dataset/training_data/re/11.png written!
# dataset/training_data/re/12.png written!
# dataset/training_data/re/13.png written!
# dataset/training_data/re/14.png written!
# dataset/training_data/re/15.png written!
# dataset/training_data/re/16.png written!
# dataset/training_data/re/17.png written!
# dataset/training_data/re/18.png written!
# dataset/training_data/re/19.png written!
# dataset/training_data/re/20.png written!
# dataset/training_data/re/21.png written!
# dataset/training_data/re/22.png written!
# dataset/training_data/re/23.png written!
# dataset/training_data/re/24.png written!
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-c3dde0677ae3> in <module>
#      92
#      93 ges_name = input("Enter gesture name: ")
# ---> 94 capture_images(ges_name)
#
# <ipython-input-1-c3dde0677ae3> in capture_images(ges_name)
#      41             frame = cv2.flip(frame, 1)
#      42
# ---> 43             l_h = cv2.getTrackbarPos("L - H", "Trackbars")
#      44             l_s = cv2.getTrackbarPos("L - S", "Trackbars")
#      45             l_v = cv2.getTrackbarPos("L - V", "Trackbars")
#
# error: OpenCV(4.9.0) C:\Users\Eng.RihaB\AppData\Local\Temp\pip-install-v5gtgj6u\opencv-python\opencv\modules\highgui\src\window_w32.cpp:2561: error: (-27:Null pointer) NULL window: 'Trackbars' in function 'cvGetTrackbarPos'
