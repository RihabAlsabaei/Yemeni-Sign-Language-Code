# %% [markdown]
# #Training and Evaluating Xception Model

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import tensorflow as tf
import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Out:
# WARNING:tensorflow:From c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import Input
from tensorflow.keras import utils
from tensorflow.keras import losses
from tensorflow.keras import optimizers
from tensorflow.keras import metrics
from tensorflow.keras.preprocessing import image as preprocessing_image
from tensorflow.keras import applications
from tensorflow.keras import callbacks
from tensorflow.keras.models import applications

# %% [markdown]
# #Load Pre-Trained Xception Model

# %%
lrn_rate=0.01
epoch = 20
batch_siz= 128
IMAGE_size=224

# %%
BASE_DIR = 'E:/ourProject/NewModel/Dataset'
# preprossecing and ahumantation
train_datagen = preprocessing_image.ImageDataGenerator(rescale=1/255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# Get Images form the dir
train_generator = train_datagen.flow_from_directory(os.path.join(BASE_DIR, "train"), target_size=(IMAGE_size,IMAGE_size), batch_size=batch_siz, class_mode='categorical')
validation_generator = train_datagen.flow_from_directory(os.path.join(BASE_DIR, "val"), target_size=(IMAGE_size,IMAGE_size), batch_size=batch_siz, class_mode='categorical')
# Out:
# Found 16979 images belonging to 32 classes.
# Found 3636 images belonging to 32 classes.

# %%
# Number of classes in the output layer
class_number = len(validation_generator.class_indices.keys())
class_number
# Out:
# 32

# %%
# load pre-trained Xception model and exclude top dense layer
base_model = applications.ResNet152V2(include_top=False,
                                   weights='imagenet',
                                   input_shape=(IMAGE_size,IMAGE_size,3))
# Out:
# WARNING:tensorflow:From c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 [==============================] - 776s 3us/step

# %%
print("Model input shape: {}\n".format(base_model.input_shape))
print("Model output shape: {}\n".format(base_model.output_shape))
print("Model number of layers: {}\n".format(len(base_model.layers)))
# Out:
# Model input shape: (None, 224, 224, 3)
#
# Model output shape: (None, 7, 7, 2048)
#
# Model number of layers: 564

# %% [markdown]
# #Fine-tune Xception Model

# %%
base_model.trainable = False

# %%
def fine_tune_Xception(base_model):

    inputs = Input(shape=(IMAGE_size, IMAGE_size, 3))

    x = base_model(inputs, training=False)

    x = layers.GlobalAveragePooling2D()(x)

    # final Dense layer
    outputs = layers.Dense(class_number, activation='softmax')(x)

    # define model with base_model's input
    model = models.Model(inputs=inputs, outputs=outputs)



    return model

# %% [markdown]
# #Compile Model

# %%
def compile_model(model):

    # loss
    loss = losses.categorical_crossentropy

    # optimizer
    optimizer = optimizers.Adam(learning_rate=lrn_rate)

    # metrics
    metric = [metrics.categorical_accuracy]

    # compile model with loss, optimizer, and evaluation metrics
    model.compile(optimizer, loss, metric)

    return model

# %%
model = fine_tune_Xception(base_model)
model = compile_model(model)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  resnet152v2 (Functional)    (None, 7, 7, 2048)        58331648
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 32)                65568
#
# =================================================================
# Total params: 58397216 (222.77 MB)
# Trainable params: 65568 (256.12 KB)
# Non-trainable params: 58331648 (222.52 MB)
# _________________________________________________________________

# %% [markdown]
# #Image Preprocessing And Augmentation

# %% [markdown]
# #Train Model on Custome Dataset

# %%
print("Model input shape: {}\n".format(model.input_shape))
print("Model output shape: {}\n".format(model.output_shape))
print("Model number of layers: {}\n".format(len(model.layers)))
# Out:
# Model input shape: (None, 224, 224, 3)
#
# Model output shape: (None, 32)
#
# Model number of layers: 4

# %%
early_stopping = callbacks.EarlyStopping(
     monitor='val_loss',
    patience=3,
    min_delta=0.001,
    restore_best_weights=True,
)

# %%
history = model.fit(
    train_generator,
    epochs=epoch,
    callbacks=[early_stopping],
    validation_data = validation_generator,
    )
# Out:
# Epoch 1/20
# WARNING:tensorflow:From c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 133/133 [==============================] - 2633s 20s/step - loss: 0.4750 - categorical_accuracy: 0.8734 - val_loss: 0.1221 - val_categorical_accuracy: 0.9623
# Epoch 2/20
# 133/133 [==============================] - 2564s 19s/step - loss: 0.0932 - categorical_accuracy: 0.9718 - val_loss: 0.0975 - val_categorical_accuracy: 0.9670
# Epoch 3/20
# 133/133 [==============================] - 2599s 20s/step - loss: 0.0696 - categorical_accuracy: 0.9770 - val_loss: 0.0726 - val_categorical_accuracy: 0.9805
# Epoch 4/20
# 133/133 [==============================] - 2512s 19s/step - loss: 0.0559 - categorical_accuracy: 0.9824 - val_loss: 0.0760 - val_categorical_accuracy: 0.9772
# Epoch 5/20
# 133/133 [==============================] - 2450s 18s/step - loss: 0.0616 - categorical_accuracy: 0.9800 - val_loss: 0.0571 - val_categorical_accuracy: 0.9827
# Epoch 6/20
# 133/133 [==============================] - 2457s 18s/step - loss: 0.0510 - categorical_accuracy: 0.9827 - val_loss: 0.0567 - val_categorical_accuracy: 0.9813
# Epoch 7/20
# 133/133 [==============================] - 2448s 18s/step - loss: 0.0395 - categorical_accuracy: 0.9873 - val_loss: 0.0499 - val_categorical_accuracy: 0.9846
# Epoch 8/20
# 133/133 [==============================] - 2444s 18s/step - loss: 0.0598 - categorical_accuracy: 0.9818 - val_loss: 0.0471 - val_categorical_accuracy: 0.9840
# Epoch 9/20
# 133/133 [==============================] - 2432s 18s/step - loss: 0.0395 - categorical_accuracy: 0.9876 - val_loss: 0.0788 - val_categorical_accuracy: 0.9802
# Epoch 10/20
# 133/133 [==============================] - 2414s 18s/step - loss: 0.0453 - categorical_accuracy: 0.9869 - val_loss: 0.0635 - val_categorical_accuracy: 0.9805
# Epoch 11/20
# 133/133 [==============================] - 2375s 18s/step - loss: 0.0400 - categorical_accuracy: 0.9880 - val_loss: 0.0595 - val_categorical_accuracy: 0.9816

# %% [markdown]
# #Plot Accuracy And Loss Over Time

# %%
def plot_accuracy_and_loss(history):
    plt.figure(1, figsize= (15, 10))

    # plot train and val accuracy
    plt.subplot(221)
    plt.plot(history.history['categorical_accuracy'])
    plt.plot(history.history['val_categorical_accuracy'])
    plt.title('Resnet152v2 accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')

    # plot train and val loss
    plt.subplot(222)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Resnet152v2 loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper right')

    plt.show()

# %%
plot_accuracy_and_loss(history)

# %%
# save model architecture
model_json = model.to_json()
open('ResNet152V2_model.json', 'w').write(model_json)

# save model's learned weights
model.save_weights('image_classifier_ResNet152V2.h5', overwrite=True)

# %% [markdown]
# Section of saving history

# %%
import pickle

# %%
# Assuming you have a history object returned by model.fit
def save_history_to_file(history, filename):
    with open(filename, 'wb') as file_pi:
        pickle.dump(history.history, file_pi)

# Load the history from the file
def load_history_from_file(filename):
    with open(filename, 'rb') as file_pi:
        history = pickle.load(file_pi)
    return history

# Example usage
# history = model.fit(X_train, y_train, batch_size=batch_size, nb_epoch=nb_epoch, validation_data=(X_test, y_test))
# Save the history to a file
save_history_to_file(history, 'trainHistoryDict.pkl')

# Load the history from the file
loaded_history = load_history_from_file('trainHistoryDict.pkl')

# %%
import pickle

def load_history_from_file(filename):
    with open(filename, 'rb') as file_pi:
        history = pickle.load(file_pi)
    return history

# Example usage
loaded_history = load_history_from_file('trainHistoryDict.pkl')

# %% [markdown]
# ##########################################

# %%
train_generator.labels
# Out:
# array([ 0,  0,  0, ..., 31, 31, 31])

# %%
BASE_DIR = "E:\ourProject\Inception and Xception\Dataset"

test_datagen= preprocessing_image.ImageDataGenerator(rescale=1/255)

test_set = test_datagen.flow_from_directory(os.path.join(BASE_DIR, "test"), target_size=(224,224), batch_size=128, class_mode='categorical')
# Out:
# Found 3630 images belonging to 32 classes.

# %%
y_test =test_set.labels

# %%
y_test = np.array(y_test)

# %%
y_test =y_test.reshape((-1, 1))

# %%
y_test
# Out:
# array([[ 0],
#        [ 0],
#        [ 0],
#        ...,
#        [31],
#        [31],
#        [31]])

# %%
y_pred=model.predict(test_set)
# Out:
# 29/29 [==============================] - 551s 19s/step

# %%
from sklearn.metrics import precision_score , recall_score ,classification_report, f1_score
from tensorflow.keras.preprocessing import image as preprocessing_image

# %%
classes = list(test_set.class_indices.keys())

# %%
y_pred = tf.argmax(y_pred, axis=1)

# %%
print(y_test.shape)
print(y_pred.shape)
# Out:
# (3630, 1)
# (3630,)

# %%
con_mat = tf.math.confusion_matrix(labels=y_test, predictions=y_pred).numpy()

# %%
con_mat_norm = np.around(con_mat.astype('float') / con_mat.sum(axis=1)[:, np.newaxis], decimals=2)

con_mat_df = pd.DataFrame(con_mat_norm,
                     index = classes,
                     columns = classes)

# %%
figure = plt.figure(figsize=(16, 7))
sns.heatmap(con_mat_df, annot=True,cmap=plt.cm.Blues)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label for ResNet152V2 Model')
plt.show()

# %%
print(classification_report(y_test, y_pred))
test_set.class_indices

# %%
print("Evaluate on test data")
results = model.evaluate(test_set, batch_size=128)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 29/29 [==============================] - 873s 30s/step - loss: 0.0534 - categorical_accuracy: 0.9835
# test loss, test acc: [0.0533604733645916, 0.9834710955619812]

# %%
import matplotlib.pyplot as plt

# Assuming you have the evaluation results stored in the 'evaluation' variable
loss = results[0]
accuracy = results[1]

# Create a bar plot to visualize the evaluation results
metrics = ['Loss', 'Accuracy']
values = [loss, accuracy]

plt.bar(metrics, values)
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.title('Test Results')
plt.show()
